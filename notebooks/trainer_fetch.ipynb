# %% [markdown]
# # NewtonianVAE: Fetch3D Robot

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
# Import dependencies
import sys
import os

# Add root file system to path
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname(__file__), "../")))

import matplotlib.pyplot as plt
from matplotlib import rc
import numpy as np
import torch


# Import project lib
from lib.training import Experiment
from lib.utils import load_encoder, load_pytorch_datasets, tc2np

# Notebook stuff
from ipywidgets import interact

# Enable TeX
rc("font", **{"size": 14, "family": "serif", "serif": ["Computer Modern"]})
rc("text", usetex=True)

# Set the torch device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# #### Set up the NewtonianVAE model experiment

# %%
# Specify the arguments of the experiment
model_name = "NewtonianVAE"
experiment_name = "Fetch3D"
dataset = "fetch_sl30.npz"

# Specify the model arguments
experiment_args = {
    "experiment": model_name + "-" + experiment_name,
    "embedder": model_name,
    "input_shape": [3, 64, 64],
    "agent": "VAEAgent",
    "state_dim": 4,
    "steps": 2,
    "divider": 2,
    "kl_reg": 1,  #'0.001:1.0:30:60',
    "epochs": 300,
    "batch_size": 1,
    "lr": 3e-4,
    "dataset": dataset,
    "action_dim": 4,
    "dt": 0.1,
    "rank": "diag",
}

# %% [markdown]
# #### Train the NewtonianVAE model

# %%
# Create an instance for this experiment
experiment = Experiment(experiment_args)
# Out:
# WARNING:py.warnings:/opt/conda/lib/python3.10/site-packages/torch/nn/modules/lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# Model Description
#  VAEAgent(
#   (embedder): NewtonianVAE(
#     (_encoder): Sequential(
#       (0): HaConvNet(
#         (seq): Sequential(
#           (0): Conv2d(5, 16, kernel_size=(4, 4), stride=(2, 2))
#           (1): ReLU()
#           (2): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2))
#           (3): ReLU()
#           (4): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#           (5): ReLU()
#           (6): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2))
#           (7): ReLU()
#           (8): Flatten(start_dim=1, end_dim=-1)
#         )
#       )
#       (1): Linear(in_features=512, out_features=8, bias=True)
#     )
#     (_decoder): HaDeconvNet(
#       (linear): Sequential(
#         (0): Linear(in_features=4, out_features=512, bias=True)
#       )
#       (deconv_seq): Sequential(
#         (0): ConvTranspose2d(512, 64, kernel_size=(5, 5), stride=(2, 2))
#         (1): ReLU()
#         (2): ConvTranspose2d(64, 32, kernel_size=(5, 5), stride=(2, 2))
#         (3): ReLU()
#         (4): ConvTranspose2d(32, 16, kernel_size=(6, 6), stride=(2, 2))
#         (5): ReLU()
#         (6): ConvTranspose2d(16, 3, kernel_size=(6, 6), stride=(2, 2))
#       )
#     )
#     (_transition_matrices): MLP(
#       (seq): Sequential(
#         (0): Linear(in_features=8, out_features=16, bias=True)
#         (1): ReLU()
#         (2): LazyBatchNorm1d(0, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): Linear(in_features=16, out_features=16, bias=True)
#         (4): ReLU()
#         (5): LazyBatchNorm1d(0, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): Linear(in_features=16, out_features=48, bias=True)
#         (7): Identity()
#       )
#     )
#   )
# )

# %%
# Train the model
experiment.train()
# Out:
# Epoch 000	Rec: 10.9243	KL: 3.628500	 Variational Loss: 14.5528
# Epoch 010	Rec: 9.3736	KL: 2.985043	 Variational Loss: 12.35879
# Epoch 020	Rec: 8.9367	KL: 2.802015	 Variational Loss: 11.7387
# Epoch 030	Rec: 8.7062	KL: 2.795409	 Variational Loss: 11.5016
# Epoch 040	Rec: 8.2243	KL: 2.686074	 Variational Loss: 10.9104
# Epoch 050	Rec: 8.0959	KL: 2.683675	 Variational Loss: 10.7796
# Epoch 060	Rec: 8.1879	KL: 2.818180	 Variational Loss: 11.00615117
# Epoch 070	Rec: 8.0461	KL: 2.732261	 Variational Loss: 10.7784
# Epoch 071:	Batch 0700/1000	Rec: 8.4070	KL: 2.7717434
# KeyboardInterrupt

# %% [markdown]
# #### Load the saved model

# %%
# Load the trained model parameters
experiment.load_model()

# %% [markdown]
# #### Visualise the latent space

# %%
# Visualise the latent space
experiment.visualiseLatentSpace()

# %% [markdown]
# #### Decode a point in the latent space for interpretability

# %%
@interact(X1=(-5.0, 5.0), X2=(-5.0, 5.0), X3=(-5.0, 5.0), X4=(-5.0, 5.0))
def robotDreams(X1, X2, X3, X4):
    x = [X1, X2, X3, X4]
    z = np.array([x])
    decoded = experiment.model.embedder.decode(torch.Tensor(z).to(device))
    im = tc2np(decoded)[0].swapaxes(1, 2).T
    plt.imshow(im)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
#       1 @interact(X1=(-5.0, 5.0), X2=(-5.0, 5.0), X3=(-5.0, 5.0), X4=(-5.0, 5.0))
# ----> 2 def robotDreams(X1, X2, X3, X4):
#       3     x = [X1, X2, X3, X4]
#       4     z = np.array([x])  # i think the shoulder and wrist joint are somehow swapped
#
# File /opt/conda/lib/python3.10/site-packages/ipywidgets/widgets/interaction.py:538, in _InteractFactory.__call__(self, _InteractFactory__interact_f, **kwargs)
#     536     f.widget = w
#     537 show_inline_matplotlib_plots()
# --> 538 display(w)
#     539 return f
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/formatters.py:144, in DisplayFormatter.format(self, obj, include, exclude)
#     141 format_dict = {}
#     142 md_dict = {}
# --> 144 if self.ipython_display_formatter(obj):
#     145     # object handled itself, don't proceed
#     146     return {}, {}
#     148 format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#
# File /opt/conda/lib/python3.10/site-packages/decorator.py:231, in fun(*args, **kw)
#     225 """
#     226 decorate(func, caller) decorates a function using a caller.
#     227 If the caller is a generator function, the resulting function
#     228 will be a generator function.
#     229 """
#     230 evaldict = dict(_call_=caller, _func_=func)
# --> 231 es = ''
#     232 for i, extra in enumerate(extras):
#     233     ex = '_e%d_' % i
#
# NameError: name 'fix' is not defined
